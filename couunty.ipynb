# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunJadhav-data/Data_Science/blob/main/couunty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pyspark as ps

# %%
data = pd.read_excel('/content/Sales Data Set for Dashboard.xlsx')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Slicer List extension is not supported and will be removed
#   warn(msg)

# %%
data.head()
# Out:
#        Unnamed: 0          Unnamed: 1  Unnamed: 2  dashboard
# 0             NaN                 NaN         NaN        NaN
# 1      Row Labels  Count of Ship Mode         NaN        NaN
# 2  Delivery Truck                 275         NaN        NaN
# 3     Express Air                 240         NaN        NaN
# 4     Regular Air                1437         NaN        NaN

# %%
data=pd.read_csv('/content/country.csv')

# %%
data.head(12)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# 5    24847         Medium      0.05        3.28           4.20           14
# 6    24848         Medium      0.05        3.58           1.63           14
# 7    18181       Critical      0.00        4.42           4.99           15
# 8    20925         Medium      0.01       35.94           6.66           15
# 9    26267           High      0.04        2.98           1.58           16
# 10   26268           High      0.05      115.99           2.50           16
# ...

# %%
data[['Country','Profit']]
# Out:
#             Country     Profit
# 0     United States     4.5600
# 1     United States  4390.3665
# 2     United States   -53.8096
# 3     United States   803.4705
# 4     United States   -24.0300
# ...             ...        ...
# 1947  United States  -116.7600
# 1948  United States  -160.9520
# 1949  United States   -41.8700
# 1950  United States   -24.7104
# 1951  United States   349.4850
#
# [1952 rows x 2 columns]

# %%
data['Profit']>0
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1947    False
# 1948    False
# 1949    False
# 1950    False
# 1951     True
# Name: Profit, Length: 1952, dtype: bool

# %%
data.describe()
# Out:
# count      1.0
# mean     996.0
# std        NaN
# min      996.0
# 25%      996.0
# 50%      996.0
# 75%      996.0
# max      996.0
# Name: count, dtype: float64

# %%
data.head(13)
# Out:
# Profit
# True    996
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1 entries, True to True
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 1 non-null      int64
# dtypes: int64(1)
# memory usage: 9.0 bytes
