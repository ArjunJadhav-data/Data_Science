# %% [markdown]
# <a href="https://colab.research.google.com/github/sonu377/Data_Science/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/BOOK.csv")

# %%
data
# Out:
#     experience   salary   id
# 0            0      NaN  101
# 1            1  10000.0  102
# 2            2  15000.0  103
# 3            3  20000.0  104
# 4            4  25000.0  105
# 5            5  30000.0  106
# 6            6  35000.0  107
# 7            7  40000.0  108
# 8            8  45000.0  109
# 9            9  50000.0  110
# 10          10  55000.0  111

# %%
data['location']=['pune','latur','nanded','nashik','kokan','pune','latur','nanded','nashik','kokan']

# %%
data
# Out:
#     experience   salary   id location
# 0            0      NaN  101     pune
# 1            1  10000.0  102    latur
# 2            2  15000.0  103   nanded
# 3            3  20000.0  104   nashik
# 4            4  25000.0  105    kokan
# 5            5  30000.0  106     pune
# 6            6  35000.0  107    latur
# 7            7  40000.0  108   nanded
# 8            8  45000.0  109   nashik
# 9            9  50000.0  110    kokan
# 10          10  55000.0  111   mumbai

# %%
data=data.rename(columns{'location':'city'})
# Out:
#   File "/tmp/ipython-input-3318095139.py", line 1
#     data=data.rename(columns{'location':'city'})
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data=data.rename(columns={'location':'city'})

# %%
data
# Out:
#     experience   salary   id    city
# 0            0      NaN  101    pune
# 1            1  10000.0  102   latur
# 2            2  15000.0  103  nanded
# 3            3  20000.0  104  nashik
# 4            4  25000.0  105   kokan
# 5            5  30000.0  106    pune
# 6            6  35000.0  107   latur
# 7            7  40000.0  108  nanded
# 8            8  45000.0  109  nashik
# 9            9  50000.0  110   kokan
# 10          10  55000.0  111  mumbai

# %%
data.isnull().sum()
# Out:
# experience    0
# salary        1
# id            0
# city          0
# dtype: int64

# %%
data['salary'].isnull()
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: salary, dtype: bool

# %%
data['salary'].fillna().mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3601586333.py in <cell line: 0>()
# ----> 1 data['salary'].fillna().mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7291                     )
#    7292
# -> 7293         value, method = validate_fillna_kwargs(value, method)
#    7294         if method is not None:
#    7295             warnings.warn(
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     291
#     292     if value is None and method is None:
# --> 293         raise ValueError("Must specify a fill 'value' or 'method'.")
#     294     if value is None and method is not None:
#     295         method = clean_fill_method(method)
#
# ...

# %%
data['salary'] = data['salary'].fillna(data['salary'].mean())

# %%
data
# Out:
#     experience   salary   id    city
# 0            0  32500.0  101    pune
# 1            1  10000.0  102   latur
# 2            2  15000.0  103  nanded
# 3            3  20000.0  104  nashik
# 4            4  25000.0  105   kokan
# 5            5  30000.0  106    pune
# 6            6  35000.0  107   latur
# 7            7  40000.0  108  nanded
# 8            8  45000.0  109  nashik
# 9            9  50000.0  110   kokan
# 10          10  55000.0  111  mumbai

# %%
data['salary'].replace(32500,0)
# Out:
# 0         0.0
# 1     10000.0
# 2     15000.0
# 3     20000.0
# 4     25000.0
# 5     30000.0
# 6     35000.0
# 7     40000.0
# 8     45000.0
# 9     50000.0
# 10    55000.0
# Name: salary, dtype: float64

# %%
ast=data['id']==101
ast
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# Name: id, dtype: bool

# %%
df=data.copy()

# %%
data.dropna('experince')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3576658571.py in <cell line: 0>()
# ----> 1 data.dropna('experince')
#
# TypeError: DataFrame.dropna() takes 1 positional argument but 2 were given

# %%
del data['id']

# %%
df
# Out:
#     experience   salary   city
# 0            0  32500.0  latur
# 1            1  10000.0  latur
# 2            2  15000.0  latur
# 3            3  20000.0  latur
# 4            4  25000.0  latur
# 5            5  30000.0  latur
# 6            6  35000.0  latur
# 7            7  40000.0  latur
# 8            8  45000.0  latur
# 9            9  50000.0  latur
# 10          10  55000.0  latur

# %%
data
# Out:
#     experience   salary   city
# 0            0  32500.0  latur
# 1            1  10000.0  latur
# 2            2  15000.0  latur
# 3            3  20000.0  latur
# 4            4  25000.0  latur
# 5            5  30000.0  latur
# 6            6  35000.0  latur
# 7            7  40000.0  latur
# 8            8  45000.0  latur
# 9            9  50000.0  latur
# 10          10  55000.0  latur

# %%
data['id']=[101,102,103,104,105,104,105,107,108,1-]

# %%
data
# Out:
#     experience   salary   city   id
# 0            0  32500.0  latur  101
# 1            1  10000.0  latur  102
# 2            2  15000.0  latur  103
# 3            3  20000.0  latur  104
# 4            4  25000.0  latur  105
# 5            5  30000.0  latur  106
# 6            6  35000.0  latur  107
# 7            7  40000.0  latur  108
# 8            8  45000.0  latur  109
# 9            9  50000.0  latur  110
# 10          10  55000.0  latur  111

# %%
df=data.copy();

# %%
data['id'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: id, dtype: bool

# %%
data=data['id'].replace(110,104)

# %%
data['id'].duplicated()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-169254990.py in <cell line: 0>()
# ----> 1 data['id'].duplicated()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression

# %%
data
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     104
# 10    111
# Name: id, dtype: int64

# %%
df
# Out:
#     experience   salary   city   id
# 0            0  32500.0  latur  101
# 1            1  10000.0  latur  102
# 2            2  15000.0  latur  103
# 3            3  20000.0  latur  104
# 4            4  25000.0  latur  105
# 5            5  30000.0  latur  106
# 6            6  35000.0  latur  107
# 7            7  40000.0  latur  108
# 8            8  45000.0  latur  109
# 9            9  50000.0  latur  110
# 10          10  55000.0  latur  111

# %%
X=df[['experience']]

# %%
y=df[['salary']]

# %%
model = LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[12]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[58750.]])
